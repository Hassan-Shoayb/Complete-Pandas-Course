# %%
import pandas as pd

# %% [markdown]
# # LOAD DATA

# %%
data = pd.read_csv('Data/sales.csv')

# %%
data.head(10)
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California              63        Amaretto    109  Major Market    -131
# 1  California              55       Green Tea    201  Major Market      88
# 2  California             143     Caffe Mocha    289  Major Market      25
# 3  California             113  Decaf Espresso    576  Major Market     216
# 4  California              37       Chamomile    247  Major Market     148
# 5  California              99           Lemon    582  Major Market     291
# 6  California              25            Mint     90  Major Market      26
# 7  California              43      Darjeeling    276  Major Market     120
# 8  California              32       Earl Grey    187  Major Market      79
# 9  California             142       Columbian    687  Major Market     364
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee       2947  Regular
# 1   West         24          Tea        659  Regular
# 2   West        109     Espresso        788  Regular
# 3   West         81     Espresso       1744    Decaf
# 4   West         26   Herbal Tea        809    Decaf
# 5   West         77   Herbal Tea       1268    Decaf
# 6   West         12   Herbal Tea        541    Decaf
# 7   West         31          Tea        897  Regular
# 8   West         21          Tea        580  Regular
# 9   West         90       Coffee       2067  Regular

# %%
data.tail()
# Out:
#           State  Total Expenses     Product  Sales   Market Size  Profit  \
# 4236  Wisconsin              34  Darjeeling     90  Small Market      20
# 4237  Wisconsin              36  Darjeeling    113  Small Market      31
# 4238  Wisconsin              86   Earl Grey    150  Small Market       1
# 4239  Wisconsin              79   Earl Grey    131  Small Market      -3
# 4240  Wisconsin              87   Earl Grey    165  Small Market       4
#
#        Market  Marketing Product Type  Inventory     Type
# 4236  Central         11          Tea        458  Regular
# 4237  Central         14          Tea        454  Regular
# 4238  Central         57          Tea        506  Regular
# 4239  Central         49          Tea        627  Regular
# 4240  Central         58          Tea        513  Regular

# %%
data.shape
# Out:
# (4241, 11)

# %% [markdown]
# # PANDAS DATAFRAMES AND SERIES

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4241 entries, 0 to 4240
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           4241 non-null   object
#  1   Total Expenses  4241 non-null   int64
#  2   Product         4241 non-null   object
#  3   Sales           4241 non-null   int64
#  4   Market Size     4241 non-null   object
#  5   Profit          4241 non-null   int64
#  6   Market          4241 non-null   object
#  7   Marketing       4241 non-null   int64
#  8   Product Type    4241 non-null   object
#  9   Inventory       4241 non-null   int64
#  10  Type            4241 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 364.6+ KB

# %%
data.describe()
# Out:
#        Total Expenses        Sales       Profit    Marketing    Inventory
# count     4241.000000  4241.000000  4241.000000  4241.000000  4241.000000
# mean        53.986560   192.601981    60.967932    31.124499   748.052110
# std         32.287864   150.545131   101.422779    26.983618   660.441587
# min         10.000000    17.000000  -638.000000     0.000000 -3534.000000
# 25%         33.000000   100.000000    17.000000    13.000000   432.000000
# 50%         46.000000   138.000000    40.000000    22.000000   619.000000
# 75%         65.000000   230.000000    92.000000    39.000000   901.000000
# max        190.000000   912.000000   778.000000   156.000000  8252.000000

# %%
insects = ['Ant', 'Cricket', 'Bee']

# %%
type(insects)
# Out:
# list

# %%
data_insects = pd.DataFrame(insects, columns=['Insects'])
data_insects
# Out:
#    Insects
# 0      Ant
# 1  Cricket
# 2      Bee

# %%
animals = {'Mammals': ['Cow', 'Sheep', 'Lion'], 
           'Reptiles': ['Crocodile', 'Lizard', 'Snake'],
           'Insects': ['Ant', 'Cricket', 'Bee']}

# %%
type(animals)
# Out:
# dict

# %%
data_animals = pd.DataFrame(animals)
data_animals
# Out:
#   Mammals   Reptiles  Insects
# 0     Cow  Crocodile      Ant
# 1   Sheep     Lizard  Cricket
# 2    Lion      Snake      Bee

# %%
data_animals['Mammals']
# Out:
# 0      Cow
# 1    Sheep
# 2     Lion
# Name: Mammals, dtype: object

# %%
type(data_animals.Reptiles)
# Out:
# pandas.core.series.Series

# %%
data_animals.iloc[0]
# Out:
# Mammals           Cow
# Reptiles    Crocodile
# Insects           Ant
# Name: 0, dtype: object

# %%
type(data_animals.iloc[1])
# Out:
# pandas.core.series.Series

# %%
data_animals.iloc[[0, 1]]
# Out:
#   Mammals   Reptiles  Insects
# 0     Cow  Crocodile      Ant
# 1   Sheep     Lizard  Cricket

# %% [markdown]
# # INDEXES

# %%
data.head()
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California              63        Amaretto    109  Major Market    -131
# 1  California              55       Green Tea    201  Major Market      88
# 2  California             143     Caffe Mocha    289  Major Market      25
# 3  California             113  Decaf Espresso    576  Major Market     216
# 4  California              37       Chamomile    247  Major Market     148
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee       2947  Regular
# 1   West         24          Tea        659  Regular
# 2   West        109     Espresso        788  Regular
# 3   West         81     Espresso       1744    Decaf
# 4   West         26   Herbal Tea        809    Decaf

# %%
data.iloc[4]
# Out:
# State               California
# Total Expenses              37
# Product              Chamomile
# Sales                      247
# Market Size       Major Market
# Profit                     148
# Market                    West
# Marketing                   26
# Product Type        Herbal Tea
# Inventory                  809
# Type                     Decaf
# Name: 4, dtype: object

# %%
# data.loc['California']

# %%
# data.loc['Colorado']

# %%
new_data = data.head()

# %%
new_data
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California              63        Amaretto    109  Major Market    -131
# 1  California              55       Green Tea    201  Major Market      88
# 2  California             143     Caffe Mocha    289  Major Market      25
# 3  California             113  Decaf Espresso    576  Major Market     216
# 4  California              37       Chamomile    247  Major Market     148
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee       2947  Regular
# 1   West         24          Tea        659  Regular
# 2   West        109     Espresso        788  Regular
# 3   West         81     Espresso       1744    Decaf
# 4   West         26   Herbal Tea        809    Decaf

# %%
indexes = ['One', 'Two', 'Three', 'Four', 'Five']

# %%
new_data.set_index([indexes], inplace=True)

# %%
new_data
# Out:
#             State  Total Expenses         Product  Sales   Market Size  \
# One    California              63        Amaretto    109  Major Market
# Two    California              55       Green Tea    201  Major Market
# Three  California             143     Caffe Mocha    289  Major Market
# Four   California             113  Decaf Espresso    576  Major Market
# Five   California              37       Chamomile    247  Major Market
#
#        Profit Market  Marketing Product Type  Inventory     Type
# One      -131   West         40       Coffee       2947  Regular
# Two        88   West         24          Tea        659  Regular
# Three      25   West        109     Espresso        788  Regular
# Four      216   West         81     Espresso       1744    Decaf
# Five      148   West         26   Herbal Tea        809    Decaf

# %%
new_data.loc['Two']
# Out:
# State               California
# Total Expenses              55
# Product              Green Tea
# Sales                      201
# Market Size       Major Market
# Profit                      88
# Market                    West
# Marketing                   24
# Product Type               Tea
# Inventory                  659
# Type                   Regular
# Name: Two, dtype: object

# %%
type(new_data.loc['Five'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # FILTERING DATA

# %%
data
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California              63        Amaretto    109  Major Market    -131
# 1     California              55       Green Tea    201  Major Market      88
# 2     California             143     Caffe Mocha    289  Major Market      25
# 3     California             113  Decaf Espresso    576  Major Market     216
# 4     California              37       Chamomile    247  Major Market     148
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin              34      Darjeeling     90  Small Market      20
# 4237   Wisconsin              36      Darjeeling    113  Small Market      31
# 4238   Wisconsin              86       Earl Grey    150  Small Market       1
# 4239   Wisconsin              79       Earl Grey    131  Small Market      -3
# 4240   Wisconsin              87       Earl Grey    165  Small Market       4
#
#        Market  Marketing Product Type  Inventory     Type
# 0        West         40       Coffee       2947  Regular
# 1        West         24          Tea        659  Regular
# 2        West        109     Espresso        788  Regular
# 3        West         81     Espresso       1744    Decaf
# 4        West         26   Herbal Tea        809    Decaf
# ...       ...        ...          ...        ...      ...
# 4236  Central         11          Tea        458  Regular
# 4237  Central         14          Tea        454  Regular
# 4238  Central         57          Tea        506  Regular
# 4239  Central         49          Tea        627  Regular
# 4240  Central         58          Tea        513  Regular
#
# [4241 rows x 11 columns]

# %%
highest_sales = (data['Sales'] > 300)

# %%
highest_sales
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4236    False
# 4237    False
# 4238    False
# 4239    False
# 4240    False
# Name: Sales, Length: 4241, dtype: bool

# %%
data.loc[highest_sales]
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 3     California             113  Decaf Espresso    576  Major Market     216
# 5     California              99           Lemon    582  Major Market     291
# 9     California             142       Columbian    687  Major Market     364
# 10    California             166       Columbian    902  Major Market     508
# 11    California             139       Columbian    664  Major Market     349
# ...          ...             ...             ...    ...           ...     ...
# 3932  Washington              71       Chamomile    329  Small Market     171
# 3933  Washington              73       Chamomile    334  Small Market     171
# 4004  Washington              75       Chamomile    347  Small Market     179
# 4122   Wisconsin             149       Columbian    317  Small Market      35
# 4213   Wisconsin             139       Columbian    314  Small Market      48
#
#        Market  Marketing Product Type  Inventory     Type
# 3        West         81     Espresso       1744    Decaf
# 5        West         77   Herbal Tea       1268    Decaf
# 9        West         90       Coffee       2067  Regular
# 10       West        127       Coffee       2617  Regular
# 11       West         87       Coffee       2580  Regular
# ...       ...        ...          ...        ...      ...
# 3932     West         40   Herbal Tea        932    Decaf
# 3933     West         41   Herbal Tea       1119    Decaf
# 4004     West         40   Herbal Tea        961    Decaf
# 4122  Central        120       Coffee        705  Regular
# 4213  Central        120       Coffee        705  Regular
#
# [670 rows x 11 columns]

# %%
data.loc[highest_sales, ['Product', 'Profit', 'Sales']]
# Out:
#              Product  Profit  Sales
# 3     Decaf Espresso     216    576
# 5              Lemon     291    582
# 9          Columbian     364    687
# 10         Columbian     508    902
# 11         Columbian     349    664
# ...              ...     ...    ...
# 3932       Chamomile     171    329
# 3933       Chamomile     171    334
# 4004       Chamomile     179    347
# 4122       Columbian      35    317
# 4213       Columbian      48    314
#
# [670 rows x 3 columns]

# %%
data['Product'].unique()
# Out:
# array(['Amaretto', 'Green Tea', 'Caffe Mocha', 'Decaf Espresso',
#        'Chamomile', 'Lemon', 'Mint', 'Darjeeling', 'Earl Grey',
#        'Columbian', 'Caffe Latte', 'Decaf Irish Cream',
#        'Regular Espresso'], dtype=object)

# %%
products = ['Green Tea', 'Lemon', 'Mint']

# %%
filt = data['Product'].isin(products)

# %%
data[filt]
# Out:
#            State  Total Expenses    Product  Sales   Market Size  Profit  \
# 1     California              55  Green Tea    201  Major Market      88
# 5     California              99      Lemon    582  Major Market     291
# 6     California              25       Mint     90  Major Market      26
# 12    California              54  Green Tea    168  Major Market      47
# 17    California              88      Lemon    467  Major Market     165
# ...          ...             ...        ...    ...           ...     ...
# 4193   Wisconsin              25      Lemon    143  Small Market      80
# 4194   Wisconsin              20      Lemon     83  Small Market      40
# 4195   Wisconsin              21      Lemon     91  Small Market      45
# 4230   Wisconsin              27      Lemon    144  Small Market      58
# 4231   Wisconsin              25      Lemon    123  Small Market      64
#
#        Market  Marketing Product Type  Inventory     Type
# 1        West         24          Tea        659  Regular
# 5        West         77   Herbal Tea       1268    Decaf
# 6        West         12   Herbal Tea        541    Decaf
# 12       West         22          Tea        677  Regular
# 17       West         66   Herbal Tea        923    Decaf
# ...       ...        ...          ...        ...      ...
# 4193  Central         16   Herbal Tea        842    Decaf
# 4194  Central          8   Herbal Tea        856    Decaf
# 4195  Central          9   Herbal Tea        863    Decaf
# 4230  Central         16   Herbal Tea        842    Decaf
# 4231  Central         13   Herbal Tea        772    Decaf
#
# [959 rows x 11 columns]

# %% [markdown]
# # UPDATING ROWS AND COLUMNS

# %%
data.columns
# Out:
# Index(['State', 'Total Expenses', 'Product', 'Sales', 'Market Size', 'Profit',
#        'Market', 'Marketing', 'Product Type', 'Inventory', 'Type'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.head()
# Out:
#         State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0  California              63        Amaretto    109  Major Market    -131
# 1  California              55       Green Tea    201  Major Market      88
# 2  California             143     Caffe Mocha    289  Major Market      25
# 3  California             113  Decaf Espresso    576  Major Market     216
# 4  California              37       Chamomile    247  Major Market     148
#
#   Market  Marketing Product_Type  Inventory     Type
# 0   West         40       Coffee       2947  Regular
# 1   West         24          Tea        659  Regular
# 2   West        109     Espresso        788  Regular
# 3   West         81     Espresso       1744    Decaf
# 4   West         26   Herbal Tea        809    Decaf

# %%
data.Product_Type
# Out:
# 0           Coffee
# 1              Tea
# 2         Espresso
# 3         Espresso
# 4       Herbal Tea
#            ...
# 4236           Tea
# 4237           Tea
# 4238           Tea
# 4239           Tea
# 4240           Tea
# Name: Product_Type, Length: 4241, dtype: object
